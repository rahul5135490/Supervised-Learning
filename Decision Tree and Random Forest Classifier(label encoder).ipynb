# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
animals=pd.read_csv("horse.csv")

# %%
animals.head()
# Out:
#   surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0      no  adult           530101         38.5   66.0              28.0
# 1     yes  adult           534817         39.2   88.0              20.0
# 2      no  adult           530334         38.3   40.0              24.0
# 3     yes  young          5290409         39.1  164.0              84.0
# 4      no  adult           530255         37.3  104.0              35.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced             NaN            more_3_sec
# 1                 NaN              NaN   pale_cyanotic            less_3_sec
# 2              normal           normal       pale_pink            less_3_sec
# 3                cold           normal   dark_cyanotic            more_3_sec
# 4                 NaN              NaN   dark_cyanotic            more_3_sec
#
#    ... packed_cell_volume total_protein abdomo_appearance abdomo_protein  \
# 0  ...               45.0           8.4               NaN            NaN
# 1  ...               50.0          85.0            cloudy            2.0
# 2  ...               33.0           6.7               NaN            NaN
# 3  ...               48.0           7.2     serosanguious            5.3
# 4  ...               74.0           7.4               NaN            NaN
#
#       outcome  surgical_lesion lesion_1 lesion_2  lesion_3  cp_data
# 0        died               no    11300        0         0       no
# 1  euthanized               no     2208        0         0       no
# 2       lived               no        0        0         0      yes
# 3        died              yes     2208        0         0      yes
# 4        died               no     4300        0         0       no
#
# [5 rows x 28 columns]

# %%
target=animals["outcome"]

# %%
target.unique()
# Out:
# array(['died', 'euthanized', 'lived'], dtype=object)

# %%
animals=animals.drop(["outcome"], axis=1)

# %%
animals.head()
# Out:
#   surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0      no  adult           530101         38.5   66.0              28.0
# 1     yes  adult           534817         39.2   88.0              20.0
# 2      no  adult           530334         38.3   40.0              24.0
# 3     yes  young          5290409         39.1  164.0              84.0
# 4      no  adult           530255         37.3  104.0              35.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced             NaN            more_3_sec
# 1                 NaN              NaN   pale_cyanotic            less_3_sec
# 2              normal           normal       pale_pink            less_3_sec
# 3                cold           normal   dark_cyanotic            more_3_sec
# 4                 NaN              NaN   dark_cyanotic            more_3_sec
#
#    ...        abdomen packed_cell_volume total_protein abdomo_appearance  \
# 0  ...  distend_large               45.0           8.4               NaN
# 1  ...          other               50.0          85.0            cloudy
# 2  ...         normal               33.0           6.7               NaN
# 3  ...            NaN               48.0           7.2     serosanguious
# 4  ...            NaN               74.0           7.4               NaN
#
#   abdomo_protein  surgical_lesion lesion_1 lesion_2  lesion_3  cp_data
# 0            NaN               no    11300        0         0       no
# 1            2.0               no     2208        0         0       no
# 2            NaN               no        0        0         0      yes
# 3            5.3              yes     2208        0         0      yes
# 4            NaN               no     4300        0         0       no
#
# [5 rows x 27 columns]

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   surgery                299 non-null    object
#  1   age                    299 non-null    object
#  2   hospital_number        299 non-null    int64
#  3   rectal_temp            239 non-null    float64
#  4   pulse                  275 non-null    float64
#  5   respiratory_rate       241 non-null    float64
#  6   temp_of_extremities    243 non-null    object
#  7   peripheral_pulse       230 non-null    object
#  8   mucous_membrane        252 non-null    object
#  9   capillary_refill_time  267 non-null    object
#  10  pain                   244 non-null    object
#  11  peristalsis            255 non-null    object
#  12  abdominal_distention   243 non-null    object
#  13  nasogastric_tube       195 non-null    object
#  14  nasogastric_reflux     193 non-null    object
#  15  nasogastric_reflux_ph  53 non-null     float64
#  16  rectal_exam_feces      197 non-null    object
#  17  abdomen                181 non-null    object
#  18  packed_cell_volume     270 non-null    float64
#  19  total_protein          266 non-null    float64
#  20  abdomo_appearance      134 non-null    object
#  21  abdomo_protein         101 non-null    float64
#  22  surgical_lesion        299 non-null    object
#  23  lesion_1               299 non-null    int64
#  24  lesion_2               299 non-null    int64
#  25  lesion_3               299 non-null    int64
#  26  cp_data                299 non-null    object
# dtypes: float64(7), int64(4), object(16)
# memory usage: 63.2+ KB

# %%
category_variables=["surgery","age","temp_of_extremities", "peripheral_pulse","mucous_membrane","capillary_refill_time","pain","peristalsis","abdominal_distention","nasogastric_tube","nasogastric_reflux","rectal_exam_feces","abdomen","abdomo_appearance","surgical_lesion","cp_data"]

# %%
for word in category_variables:
    animals = pd.get_dummies(animals)

# %%
animals
# Out:
#      hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0             530101         38.5   66.0              28.0
# 1             534817         39.2   88.0              20.0
# 2             530334         38.3   40.0              24.0
# 3            5290409         39.1  164.0              84.0
# 4             530255         37.3  104.0              35.0
# ..               ...          ...    ...               ...
# 294           533886          NaN  120.0              70.0
# 295           527702         37.2   72.0              24.0
# 296           529386         37.5   72.0              30.0
# 297           530612         36.5  100.0              24.0
# 298           534618         37.2   40.0              20.0
#
#      nasogastric_reflux_ph  packed_cell_volume  total_protein  abdomo_protein  \
# 0                      NaN                45.0            8.4             NaN
# 1                      NaN                50.0           85.0             2.0
# 2                      NaN                33.0            6.7             NaN
# 3                      5.0                48.0            7.2             5.3
# 4                      NaN                74.0            7.4             NaN
# ..                     ...                 ...            ...             ...
# 294                    NaN                55.0           65.0             NaN
# 295                    NaN                44.0            NaN             3.3
# 296                    NaN                60.0            6.8             NaN
# 297                    NaN                50.0            6.0             3.4
# 298                    NaN                36.0           62.0             1.0
#
#      lesion_1  lesion_2  ...  abdomen_firm  abdomen_normal  abdomen_other  \
# 0       11300         0  ...             0               0              0
# 1        2208         0  ...             0               0              1
# 2           0         0  ...             0               1              0
# 3        2208         0  ...             0               0              0
# 4        4300         0  ...             0               0              0
# ..        ...       ...  ...           ...             ...            ...
# 294      3205         0  ...             0               0              0
# 295      2208         0  ...             0               0              0
# 296      3205         0  ...             0               0              0
# 297      2208         0  ...             0               0              0
# 298      6112         0  ...             0               1              0
#
#      abdomo_appearance_clear  abdomo_appearance_cloudy  \
# 0                          0                         0
# 1                          0                         1
# 2                          0                         0
# 3                          0                         0
# 4                          0                         0
# ..                       ...                       ...
# 294                        0                         0
# 295                        0                         0
# 296                        0                         0
# 297                        0                         0
# 298                        1                         0
#
#      abdomo_appearance_serosanguious  surgical_lesion_no  surgical_lesion_yes  \
# 0                                  0                   1                    0
# 1                                  0                   1                    0
# 2                                  0                   1                    0
# 3                                  1                   0                    1
# 4                                  0                   1                    0
# ..                               ...                 ...                  ...
# 294                                0                   1                    0
# 295                                1                   0                    1
# 296                                0                   0                    1
# 297                                1                   0                    1
# 298                                0                   1                    0
#
#      cp_data_no  cp_data_yes
# 0             1            0
# 1             1            0
# 2             0            1
# 3             0            1
# 4             1            0
# ..          ...          ...
# 294           1            0
# 295           0            1
# 296           1            0
# 297           0            1
# 298           1            0
#
# [299 rows x 67 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
X=animals

# %%
y=target

# %%
X.head()
# Out:
#    hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0           530101         38.5   66.0              28.0
# 1           534817         39.2   88.0              20.0
# 2           530334         38.3   40.0              24.0
# 3          5290409         39.1  164.0              84.0
# 4           530255         37.3  104.0              35.0
#
#    nasogastric_reflux_ph  packed_cell_volume  total_protein  abdomo_protein  \
# 0                    NaN                45.0            8.4             NaN
# 1                    NaN                50.0           85.0             2.0
# 2                    NaN                33.0            6.7             NaN
# 3                    5.0                48.0            7.2             5.3
# 4                    NaN                74.0            7.4             NaN
#
#    lesion_1  lesion_2  ...  abdomen_firm  abdomen_normal  abdomen_other  \
# 0     11300         0  ...             0               0              0
# 1      2208         0  ...             0               0              1
# 2         0         0  ...             0               1              0
# 3      2208         0  ...             0               0              0
# 4      4300         0  ...             0               0              0
#
#    abdomo_appearance_clear  abdomo_appearance_cloudy  \
# 0                        0                         0
# 1                        0                         1
# 2                        0                         0
# 3                        0                         0
# 4                        0                         0
#
#    abdomo_appearance_serosanguious  surgical_lesion_no  surgical_lesion_yes  \
# 0                                0                   1                    0
# 1                                0                   1                    0
# 2                                0                   1                    0
# 3                                1                   0                    1
# 4                                0                   1                    0
#
#    cp_data_no  cp_data_yes
# 0           1            0
# 1           1            0
# 2           0            1
# 3           0            1
# 4           1            0
#
# [5 rows x 67 columns]

# %%
y.unique()
# Out:
# array(['died', 'euthanized', 'lived'], dtype=object)

# %%
label_encoder=LabelEncoder()

# %%
y= label_encoder.fit_transform(y)

# %%
y
# Out:
# array([0, 1, 2, 0, 0, 2, 2, 0, 1, 2, 2, 2, 2, 0, 2, 0, 0, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 0, 2, 0, 1, 2, 2, 2, 1, 1, 2, 2, 0, 0, 2, 2, 1,
#        1, 0, 2, 2, 0, 0, 2, 0, 2, 2, 1, 0, 2, 0, 0, 0, 2, 2, 0, 1, 2, 2,
#        2, 2, 2, 2, 1, 2, 0, 0, 0, 1, 2, 2, 0, 2, 0, 2, 2, 0, 2, 2, 0, 1,
#        2, 2, 2, 0, 2, 0, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 0, 2, 2, 2, 1, 0,
#        0, 2, 2, 0, 2, 2, 2, 1, 2, 2, 2, 1, 2, 0, 1, 2, 2, 2, 1, 2, 0, 0,
#        2, 0, 0, 0, 2, 2, 2, 2, 0, 0, 2, 1, 2, 2, 0, 2, 2, 2, 0, 2, 2, 2,
#        2, 2, 1, 2, 2, 2, 0, 2, 1, 2, 1, 2, 2, 2, 1, 2, 0, 2, 0, 0, 2, 2,
#        0, 2, 1, 0, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 1, 0, 2,
#        2, 2, 0, 1, 2, 2, 1, 2, 0, 1, 2, 0, 0, 2, 2, 2, 2, 2, 2, 1, 2, 1,
#        2, 2, 2, 2, 2, 0, 2, 1, 2, 2, 0, 2, 2, 2, 0, 2, 2, 1, 1, 0, 2, 0,
#        2, 2, 0, 2, 0, 2, 2, 1, 0, 0, 2, 2, 0, 1, 0, 2, 0, 2, 2, 2, 0, 2,
#        1, 2, 2, 2, 2, 0, 2, 2, 0, 1, 0, 1, 2, 2, 2, 2, 0, 0, 2, 2, 2, 1,
#        2, 2, 2, 2, 0, 0, 1, 2, 1, 1, 0, 2, 1])

# %%
 X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.20, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
print(X_train.shape)
# Out:
# (239, 67)

# %%
X_train.head()
# Out:
#      hospital_number  rectal_temp  pulse  respiratory_rate  \
# 6             526802         37.9   48.0              16.0
# 183           534053         38.2   68.0              32.0
# 185          5278331         39.3   64.0              90.0
# 146           530001         38.0   44.0              12.0
# 30            529475         37.7   96.0              30.0
#
#      nasogastric_reflux_ph  packed_cell_volume  total_protein  abdomo_protein  \
# 6                      NaN                37.0            7.0             NaN
# 183                    NaN                43.0           65.0             NaN
# 185                    NaN                39.0            6.7             NaN
# 146                    6.5                33.0            6.5             NaN
# 30                     4.0                66.0            7.5             NaN
#
#      lesion_1  lesion_2  ...  abdomen_firm  abdomen_normal  abdomen_other  \
# 6        3124         0  ...             0               0              0
# 183         0         0  ...             0               1              0
# 185     21110         0  ...             0               0              0
# 146      2209         0  ...             0               0              0
# 30       4205         0  ...             0               0              0
#
#      abdomo_appearance_clear  abdomo_appearance_cloudy  \
# 6                          0                         0
# 183                        0                         0
# 185                        0                         0
# 146                        0                         0
# 30                         0                         0
#
#      abdomo_appearance_serosanguious  surgical_lesion_no  surgical_lesion_yes  \
# 6                                  0                   0                    1
# 183                                0                   1                    0
# 185                                0                   0                    1
# 146                                0                   0                    1
# 30                                 0                   0                    1
#
#      cp_data_no  cp_data_yes
# 6             1            0
# 183           1            0
# 185           1            0
# 146           1            0
# 30            1            0
#
# [5 rows x 67 columns]

# %%
print(X_test.shape)
# Out:
# (60, 67)

# %%
X_test.head()
# Out:
#      hospital_number  rectal_temp  pulse  respiratory_rate  \
# 281           527544          NaN   70.0              16.0
# 265           529865         38.6   68.0              20.0
# 164           534925         39.4  120.0              48.0
# 9            5299629         38.3   90.0               NaN
# 77            534753         38.7   52.0              20.0
#
#      nasogastric_reflux_ph  packed_cell_volume  total_protein  abdomo_protein  \
# 281                    NaN                60.0            7.5             NaN
# 265                    NaN                38.0            6.5             NaN
# 164                    NaN                56.0           64.0             2.0
# 9                      NaN                40.0            6.2             2.2
# 77                     NaN                33.0           77.0             NaN
#
#      lesion_1  lesion_2  ...  abdomen_firm  abdomen_normal  abdomen_other  \
# 281      1400         0  ...             0               0              0
# 265      5124         0  ...             0               0              0
# 164      1400         0  ...             0               0              0
# 9           0         0  ...             0               0              0
# 77          0         0  ...             0               1              0
#
#      abdomo_appearance_clear  abdomo_appearance_cloudy  \
# 281                        0                         0
# 265                        1                         0
# 164                        1                         0
# 9                          1                         0
# 77                         0                         0
#
#      abdomo_appearance_serosanguious  surgical_lesion_no  surgical_lesion_yes  \
# 281                                0                   0                    1
# 265                                0                   1                    0
# 164                                0                   1                    0
# 9                                  0                   1                    0
# 77                                 0                   1                    0
#
#      cp_data_no  cp_data_yes
# 281           1            0
# 265           0            1
# 164           1            0
# 9             0            1
# 77            1            0
#
# [5 rows x 67 columns]

# %%
# impute the missing value
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.NaN,strategy="most_frequent")

# %%
X_train= imp.fit_transform(X_train)

# %%
X_test= imp.fit_transform(X_test)

# %%
X_train
# Out:
# array([[5.268020e+05, 3.790000e+01, 4.800000e+01, ..., 1.000000e+00,
#         1.000000e+00, 0.000000e+00],
#        [5.340530e+05, 3.820000e+01, 6.800000e+01, ..., 0.000000e+00,
#         1.000000e+00, 0.000000e+00],
#        [5.278331e+06, 3.930000e+01, 6.400000e+01, ..., 1.000000e+00,
#         1.000000e+00, 0.000000e+00],
#        ...,
#        [5.286680e+05, 3.830000e+01, 5.200000e+01, ..., 1.000000e+00,
#         0.000000e+00, 1.000000e+00],
#        [5.346260e+05, 3.770000e+01, 8.000000e+01, ..., 1.000000e+00,
#         1.000000e+00, 0.000000e+00],
#        [5.349380e+05, 3.830000e+01, 4.000000e+01, ..., 0.000000e+00,
#         1.000000e+00, 0.000000e+00]])

# %%
classifier=DecisionTreeClassifier()

# %%
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_pred,y_test)

# %%
print(accuracy)
# Out:
# 0.6666666666666666

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier=RandomForestClassifier()

# %%
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)
accuracy=accuracy_score(y_pred,y_test)
print(accuracy)
# Out:
# 0.7
